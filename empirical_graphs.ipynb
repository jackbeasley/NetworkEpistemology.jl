# %%
from neo4j import GraphDatabase
import pandas as pd
import networkx as nx

# %%
driver = GraphDatabase.driver("bolt://localhost:7687", auth=("neo4j", "mag"))

# %%
def get_top_level_fields():
    TOP_LEVEL_FOS_QUERY = """
        MATCH (c:FieldsOfStudy) WHERE c.level = 0 RETURN c
    """
    with driver.session() as session:
        return pd.DataFrame(
            [dict(res['c']) for res in session.run(TOP_LEVEL_FOS_QUERY).data()]
        ).drop(['createdDate', 'mainType', 'displayName'], axis=1)

# %%
get_top_level_fields()
# Out:
#     citationCount  level  paperCount fieldOfStudyId   rank  \
# 0         5899803      0     6881470       95457728  14747
# 1         7487874      0     3977456      205649164   8880
# 2        36760247      0     4965136      127313418   8467
# 3        71789329      0     6671940       33923547   7216
# 4        89882893      0    14168189       41008148   7358
# 5       317500143      0    16932898       86803240   6663
# 6        14578948      0     4605062      144133560  25000
# 7        13219878      0     4429896       17744445   8806
# 8        43768427      0     3950679      162324750  25000
# 9        78784820      0    17935539      127413603  25000
# 10      183204437      0    16984397      185592680   6839
# 11        3092922      0     2749859      138885662  25000
# 12       89014209      0     6817436       15744967   7829
# 13       20773303      0     4216382      144024400   8436
# 14       73472446      0    18021323      192562407   6723
# 15        7959326      0     2559737       39432304   6978
# 16       74275820      0     8653590      121332964   6623
# 17      230924107      0    25980539       71924100   9444
# 18        3300182      0     5556692      142362112  25000
#
#            normalizedName
# 0                 history
# 1               geography
# 2                 geology
# 3             mathematics
# 4        computer science
# 5                 biology
# 6                business
# 7       political science
# 8               economics
# 9             engineering
# 10              chemistry
# 11             philosophy
# 12             psychology
# 13              sociology
# 14      materials science
# 15  environmental science
# 16                physics
# 17               medicine
# 18                    art

# %%
def get_subfields_by_size(parentName, minPapers, maxPapers, limit=10):
    FOS_QUERY = """
        MATCH (c:FieldsOfStudy)<-[:PARENT]-(parent:FieldsOfStudy{normalizedName: $fosName})
        WHERE c.paperCount > $minct AND c.paperCount < $maxct
        RETURN DISTINCT c
        ORDER BY c.citationCount DESC
        LIMIT $limit
    """
    with driver.session() as session:
        results = session.run(FOS_QUERY, minct=minPapers, maxct=maxPapers, limit=limit, fosName=parentName)
        return pd.DataFrame(
            [dict(res['c']) for res in results.data()]
        )

# %%
get_subfields_by_size('linguistics', 300, 800, 50)
# Out:
#     citationCount createdDate  level                          displayName  \
# 0           23498  2016-06-24      2         Social interactionist theory
# 1           22183  2018-01-05      2                      Audience design
# 2           20120  2016-06-24      2                       Biolinguistics
# 3           19685  2016-06-24      2                        Nominal group
# 4           16826  2018-01-05      2                         Brown Corpus
# 5           16043  2018-01-05      2               Radical interpretation
# 6           13328  2016-06-24      2                         Fast mapping
# 7           13219  2018-01-05      2                   Origin of language
# 8           12671  2016-06-24      2                             FrameNet
# 9           12529  2016-06-24      2       Linguistic sequence complexity
# 10          12137  2016-06-24      2                        Relative term
# 11          12109  2018-01-05      2                     Words per minute
# 12          11973  2018-01-05      2                        Function word
# 13          10992  2018-01-05      2                 Definite description
# 14          10984  2016-06-24      2                    Tense–aspect–mood
# 15          10494  2018-01-05      2                            Homograph
# 16          10477  2016-06-24      2   Communication accommodation theory
# 17          10447  2018-01-05      2                    Input enhancement
# 18          10197  2018-01-05      2                Linguistic validation
# 19          10162  2016-06-24      2                        Phonetic form
# 20           9731  2018-01-05      2                             Mouthing
# 21           9616  2018-01-05      2                             Highbrow
# 22           9553  2018-01-05      2                     Natural approach
# 23           9511  2018-01-05      2                   Speech acquisition
# 24           9455  2018-01-05      2                    Linguistic system
# 25           8859  2018-01-05      2            Content-based instruction
# 26           8727  2018-01-05      2               Interaction hypothesis
# 27           8640  2018-01-05      2               Propositional attitude
# 28           8548  2018-01-05      2               Linguistic imperialism
# 29           8547  2018-01-05      2                               Thrall
# 30           8466  2018-01-05      2                Historical pragmatics
# 31           8330  2018-01-05      2  African American Vernacular English
# 32           8242  2016-06-24      2                         Antisymmetry
# 33           8168  2018-01-05      2                        Genre studies
# 34           8065  2018-01-05      2                   Eastern Hemisphere
# 35           7977  2018-01-05      2                       Language death
# 36           7126  2018-01-05      2                             Disjunct
# 37           7047  2018-01-05      2                         Speech delay
# 38           6901  2018-01-05      2                             Rudeness
# 39           6847  2018-01-05      2                           Epistemics
# 40           6573  2018-01-05      2                         Succinctness
# 41           6490  2016-06-24      2                      Sound symbolism
# 42           6432  2018-01-05      2                              Anagram
# 43           6324  2018-01-05      2                      Counterargument
# 44           6322  2018-01-05      2                             Shoshana
# 45           6312  2018-01-05      2                     Tacit assumption
# 46           6096  2016-06-24      2                 Full-time equivalent
# 47           6067  2018-01-05      2                  New Zealand English
# 48           6062  2018-01-05      2                             Polyglot
# 49           6032  2018-01-05      2                       Lombard effect
#
#     paperCount fieldOfStudyId   rank                       normalizedName  \
# 0          313       79500916  16876         social interactionist theory
# 1          322     2778906372  14805                      audience design
# 2          327       35511919  15108                       biolinguistics
# 3          631      141728528  14905                        nominal group
# 4          314     2777744975  15165                         brown corpus
# 5          373     2778569360  15556               radical interpretation
# 6          690      117015117  14783                         fast mapping
# 7          763     2780989915  14542                   origin of language
# 8          791      185754541  15122                             framenet
# 9          627      194926167  14749       linguistic sequence complexity
# 10         336       76050143  19195                        relative term
# 11         662     2777970837  13527                     words per minute
# 12         623     2781403456  13786                        function word
# 13         601     2778072359  13498                 definite description
# 14         661      187714233  18175                    tense aspect mood
# 15         450     2776540068  14143                            homograph
# 16         576       55091264  14642   communication accommodation theory
# 17         334     2776926597  15467                    input enhancement
# 18         405     2777361623  15431                linguistic validation
# 19         508      161687759  17038                        phonetic form
# 20         528     2781039439  15869                             mouthing
# 21         786     2776662206  16995                             highbrow
# 22         638     2778668247  15656                     natural approach
# 23         509     2780857552  15375                   speech acquisition
# 24         656     2778713422  15400                    linguistic system
# 25         564     2780518247  14437            content based instruction
# 26         344     2779556734  15941               interaction hypothesis
# 27         795     2780642385  13432               propositional attitude
# 28         421     2776899900  15438               linguistic imperialism
# 29         441     2780558819  16235                               thrall
# 30         418     2776520548  14373                historical pragmatics
# 31         450     2775884164  14661  african american vernacular english
# 32         595      114825156  14802                         antisymmetry
# 33         448     2779655241  15465                        genre studies
# 34         536     2775921472  13498                   eastern hemisphere
# 35         526     2780179078  14939                       language death
# 36         634     2781445333  15826                             disjunct
# 37         511     2779688443  15035                         speech delay
# 38         532     2781446942  14716                             rudeness
# 39         402     2778962883  15086                           epistemics
# 40         490     2776493592  15506                         succinctness
# 41         685       18020764  14165                      sound symbolism
# 42         723     2777996765  15506                              anagram
# 43         428     2778988046  16581                      counterargument
# 44         381     2779197124  15896                             shoshana
# 45         402     2777939231  16823                     tacit assumption
# 46         569      126763645  13418                 full time equivalent
# 47         576     2779009331  14443                  new zealand english
# 48         759     2780239667  16377                             polyglot
# 49         325     2776509809  14871                       lombard effect
#
#                    mainType
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7                       NaN
# 8                       NaN
# 9                       NaN
# 10                      NaN
# 11                      NaN
# 12                      NaN
# 13                      NaN
# 14                      NaN
# 15                      NaN
# 16                      NaN
# 17                      NaN
# 18                      NaN
# 19                      NaN
# 20                      NaN
# 21                      NaN
# 22                      NaN
# 23                      NaN
# 24                      NaN
# 25                      NaN
# 26                      NaN
# 27                      NaN
# 28                      NaN
# 29                      NaN
# 30                      NaN
# 31                      NaN
# 32                      NaN
# 33                      NaN
# 34                      NaN
# 35                      NaN
# 36                      NaN
# 37         medicine.symptom
# 38                      NaN
# 39                      NaN
# 40                      NaN
# 41                      NaN
# 42                      NaN
# 43                      NaN
# 44                      NaN
# 45                      NaN
# 46                      NaN
# 47  language.human_language
# 48                      NaN
# 49                      NaN

# %%
def get_child_fields_by_id(parentFosID):
    CHILD_FOS_QUERY = """
        MATCH (c:FieldsOfStudy)<-[:PARENT]-(parent:FieldsOfStudy{fieldOfStudyId: $fosid}) RETURN c
    """
    with driver.session() as session:
        return pd.DataFrame(
            [dict(res['c']) for res in session.run(CHILD_FOS_QUERY, fosid=parentFosID).data()]
        ).drop(['createdDate', 'mainType', 'displayName'], axis=1)

def get_child_fields_by_name(parentName):
    CHILD_FOS_QUERY = """
        MATCH (c:FieldsOfStudy)<-[:PARENT]-(parent:FieldsOfStudy{normalizedName: $fosName}) 
        RETURN c
        ORDER BY c.paperCount
    """
    with driver.session() as session:
        return pd.DataFrame(
            [dict(res['c']) for res in session.run(CHILD_FOS_QUERY, fosName=parentName).data()]
        ).drop(['createdDate', 'mainType', 'displayName'], axis=1)

# %%
get_child_fields_by_name("social epistemology")
# Out:
#    citationCount  level  paperCount fieldOfStudyId   rank  \
# 0           8309      3         945      184066805  14430
# 1          10257      3        1192       73059102  15975
# 2          14898      3        1771      145097170  25000
#
#               normalizedName
# 0       genetic epistemology
# 1        formal epistemology
# 2  epistemology of wikipedia

# %%
def get_authors(fieldOfStudyName):
    AUTHOR_QUERY = """
        MATCH (p:Paper)-[:IN_FIELD]->(parent:FieldsOfStudy{normalizedName: $name}) WITH p
        MATCH (p)-[:AUTHORED_BY]->(a:Author)
        RETURN DISTINCT a
        ORDER BY a.citationCount DESC
    """
    with driver.session() as session:
        return pd.DataFrame(
            [dict(res['a']) for res in session.run(AUTHOR_QUERY, name=fieldOfStudyName).data()]
        ).drop(['createdDate', 'displayName'], axis=1)

# %%
res = get_authors("social epistemology")
res[res.normalizedName.str.startswith('kevin')]
# Out:
#       citationCount  paperCount   rank    authorId     normalizedName
# 447            1101          71  15392  2097678952      kevin t kelly
# 648             551          32  16732  2088804034  kevin j s zollman
# 885             276          34  16756  2053622605    kevin t jackson
# 1046            171          47  16846  2071876023       kevin mccain
# 1998              8           1  20517  2720828136      kevin vallier
# 2055              7           1  19975  2792820455      kevin r gregg
# 2092              6           1  20516  2181692093     kevin williams
# 3108              0           1  20873  2688938239      kevin kurdylo
# 4083              0           1  20873  2251971931     kevin anderson
# 4106              0           1  20873  2889292227     kevin hermberg

# %%
def get_coauthor_graph(fieldOfStudyName):
    COAUTHOR_QUERY = """
        MATCH (p:Paper)-[:IN_FIELD]->(parent:FieldsOfStudy{normalizedName: $fosName}) WITH p
        MATCH (p)-[:AUTHORED_BY]->(a:Author) WITH a
        MATCH (a:Author)<-[r1:AUTHORED_BY]-(p1:Paper)-[r2:AUTHORED_BY]->(a2:Author)
        RETURN DISTINCT {start:a.normalizedName,end:a2.normalizedName}
    """

    with driver.session() as session:
        query_results = session.run(COAUTHOR_QUERY, fosName=fieldOfStudyName).data()
        edge_list = [
            (
                res['{start:a.normalizedName,end:a2.normalizedName}']["start"], 
            res['{start:a.normalizedName,end:a2.normalizedName}']['end']
            ) for res in query_results]
        G = nx.DiGraph()
        G.add_edges_from(edge_list)
        return nx.convert_node_labels_to_integers(G)

# %%
graph = get_coauthor_relations("social epistemology")

# %%
def get_papers(fieldOfStudyName):
    PAPERS_QUERY = """
        MATCH (p:Paper)-[:IN_FIELD]->(parent:FieldsOfStudy{normalizedName: $fosName})
        WHERE p.citationCount > 0 AND p.referenceCount > 0 AND p.docType = "Journal"
        RETURN p
    """

    with driver.session() as session:
        query_results = session.run(PAPERS_QUERY, fosName=fieldOfStudyName).data()
        return query_results

# %%
len(get_papers("sociolinguistics"))
# Out:
# 3787

# %%
def get_authors(fieldOfStudyName):
    AUTHORS_QUERY = """
        MATCH (p:Paper)-[:IN_FIELD]->(parent:FieldsOfStudy{normalizedName: $fosName})
        WHERE p.citationCount > 0 AND p.referenceCount > 0 AND p.docType = "Journal"
        MATCH (p)-[:AUTHORED_BY]->(a:Author)
        RETURN DISTINCT a
    """

    with driver.session() as session:
        query_results = session.run(AUTHORS_QUERY, fosName=fieldOfStudyName).data()
        return query_results

# %%
len(get_authors("sociolinguistics"))
# Out:
# 4577

# %%
res
# Out:
# [{'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2165615180',
#    'rel': 'COAUTHOR',
#    'end': '2558932145'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2165615180',
#    'rel': 'COAUTHOR',
#    'end': '2157414154'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '742588681',
#    'rel': 'COAUTHOR',
#    'end': '2625440941'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '742588681',
#    'rel': 'COAUTHOR',
#    'end': '2497628704'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '742588681',
#    'rel': 'COAUTHOR',
#    'end': '2016486316'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '742588681',
#    'rel': 'COAUTHOR',
#    'end': '1738948060'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '742588681',
#    'rel': 'COAUTHOR',
#    'end': '2505626879'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '742588681',
#    'rel': 'COAUTHOR',
#    'end': '2889341742'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '742588681',
#    'rel': 'COAUTHOR',
#    'end': '2313193659'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '742588681',
#    'rel': 'COAUTHOR',
#    'end': '2042457380'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2776164547',
#    'rel': 'COAUTHOR',
#    'end': '2776164547'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2146949505',
#    'rel': 'COAUTHOR',
#    'end': '2656946830'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2305818039',
#    'rel': 'COAUTHOR',
#    'end': '114949780'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '114949780',
#    'rel': 'COAUTHOR',
#    'end': '54950662'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '114949780',
#    'rel': 'COAUTHOR',
#    'end': '2123090499'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '114949780',
#    'rel': 'COAUTHOR',
#    'end': '2136971860'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '114949780',
#    'rel': 'COAUTHOR',
#    'end': '114949780'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '114949780',
#    'rel': 'COAUTHOR',
#    'end': '2429938104'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '114949780',
#    'rel': 'COAUTHOR',
#    'end': '2079197060'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '114949780',
#    'rel': 'COAUTHOR',
#    'end': '2305818039'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '114949780',
#    'rel': 'COAUTHOR',
#    'end': '2106848606'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1991084385',
#    'rel': 'COAUTHOR',
#    'end': '2157385811'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2013053168',
#    'rel': 'COAUTHOR',
#    'end': '1977349315'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2013053168',
#    'rel': 'COAUTHOR',
#    'end': '2343288351'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2013053168',
#    'rel': 'COAUTHOR',
#    'end': '2095319762'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2013053168',
#    'rel': 'COAUTHOR',
#    'end': '2020781963'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2013053168',
#    'rel': 'COAUTHOR',
#    'end': '2408443824'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2013053168',
#    'rel': 'COAUTHOR',
#    'end': '1354025746'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2013053168',
#    'rel': 'COAUTHOR',
#    'end': '2014778140'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2013053168',
#    'rel': 'COAUTHOR',
#    'end': '722887898'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2554865697'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2153248334'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '1582221311'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '1572976283'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2013053168'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2734829754'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '1431126395'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2786045516'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2400734185'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2287651513'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2343288351'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '112815247'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2567737182'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2552389105'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2140520855'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2514931277'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2292270104'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2650724577'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2765346714'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2071249274'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2759461588'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2758254731'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2757593424'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2757566695'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2100147617'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '1975705289'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '1846896907'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2157640589'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '676177579'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2573085743'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2126085803'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '1984809483'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '722887898'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2188592905'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2659285777'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2564685605'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2031062030'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2011752965'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2327423788'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2230512381'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2095319762'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2382147411'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2146999563'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '186019500'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2672174875'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2510852008'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2408854028'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2020781963'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2135600895'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '847645771'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2138187636'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2797589424'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2116717443'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2105982023'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2399339750'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2116376984'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '1982319685'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '707218448'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '161216892'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2575248661'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2310867954'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2292227591'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2185634243'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2183534167'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2155653594'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2139534274'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2061578873'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '1969562705'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '1653220057'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2615551904'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2615478364'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2614983542'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2614866032'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2164420943'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2129810712'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2395949265'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2806574362'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2616758951'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2143182063'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2081624886'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '1994776272'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2303987790'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2144990590'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2014778140'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2584546521'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2691453026'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2135150508'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2704103930'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2677183618'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2149458952'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2326473410'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2291429806'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2170181379'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2158884724'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2119183168'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2102284236'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '1980068948'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2566873332'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2231469369'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2126149086'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2005258395'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '1987469270'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '1504186000'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2639101323'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '676178888'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2143243998'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2507247197'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '401840786'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2646546721'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2232712810'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2083138768'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '1220807746'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2037513643'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2575919767'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '1981325106'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2463114407'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2183521611'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2160811952'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2151930756'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2112324925'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2104582966'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2102570927'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2098416792'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2093843815'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2026319576'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '1975162656'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '1075592465'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '237311555'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '207967185'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '77528956'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '29409133'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2315886003'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2129993671'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2077318795'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '1977349315',
#    'rel': 'COAUTHOR',
#    'end': '2806817040'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2422160718',
#    'rel': 'COAUTHOR',
#    'end': '2204415056'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2422160718',
#    'rel': 'COAUTHOR',
#    'end': '2108607284'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2422160718',
#    'rel': 'COAUTHOR',
#    'end': '2023861690'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2422160718',
#    'rel': 'COAUTHOR',
#    'end': '2180580011'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2422160718',
#    'rel': 'COAUTHOR',
#    'end': '2138094682'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2422160718',
#    'rel': 'COAUTHOR',
#    'end': '2717446495'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2422160718',
#    'rel': 'COAUTHOR',
#    'end': '2688969808'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2422160718',
#    'rel': 'COAUTHOR',
#    'end': '2053810251'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2422160718',
#    'rel': 'COAUTHOR',
#    'end': '2102093250'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2422160718',
#    'rel': 'COAUTHOR',
#    'end': '2130346631'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2422160718',
#    'rel': 'COAUTHOR',
#    'end': '330205485'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2422160718',
#    'rel': 'COAUTHOR',
#    'end': '1971164523'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2422160718',
#    'rel': 'COAUTHOR',
#    'end': '2106386097'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2422160718',
#    'rel': 'COAUTHOR',
#    'end': '2667590845'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2422160718',
#    'rel': 'COAUTHOR',
#    'end': '2108984791'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2422160718',
#    'rel': 'COAUTHOR',
#    'end': '2321076068'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2422160718',
#    'rel': 'COAUTHOR',
#    'end': '2146416797'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2422160718',
#    'rel': 'COAUTHOR',
#    'end': '2668379698'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2422160718',
#    'rel': 'COAUTHOR',
#    'end': '2486685949'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2422160718',
#    'rel': 'COAUTHOR',
#    'end': '2135388923'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2422160718',
#    'rel': 'COAUTHOR',
#    'end': '2627727290'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2422160718',
#    'rel': 'COAUTHOR',
#    'end': '2314801451'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2422160718',
#    'rel': 'COAUTHOR',
#    'end': '2130461369'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2422160718',
#    'rel': 'COAUTHOR',
#    'end': '2311369853'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2422160718',
#    'rel': 'COAUTHOR',
#    'end': '2146949738'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2422160718',
#    'rel': 'COAUTHOR',
#    'end': '2007553612'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2140074598'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '526137627'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2567137662'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2315886003'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2050197139'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2673207947'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2142306642'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2132866948'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2102093250'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2053810251'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2586699203'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2476288930'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2799245177'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2799031198'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2798912698'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2798597963'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2798561155'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2798555490'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2798279620'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2512799708'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2323133105'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2204415056'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2134010544'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2108607284'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2323598000'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2206994961'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2105542472'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '51199004'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2068978918'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2675005029'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2422160718'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2138094682'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2142652994'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2587694267'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2106438322'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2637020588'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2589336749'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2631319902'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2717446495'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2688969808'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2142551257'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2024306786'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2096510679'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2119973400'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2795927885'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2428513988'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '1824459930'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2127194655'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2180580011'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2007175227'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '1976914063'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2189132904'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '1909795746'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2318363409'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '559008499'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2172368290'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2655381025'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2103834333'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2668313980'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2696418575'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2799098263'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2714767587'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2098835599'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2321504710'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2009862704'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2103691184'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '339795999'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2439632951'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2417951899'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2159054773'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2115870330'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2113940068'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2139865410'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2137276256'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2311369853'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2290916714'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '412188621'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2565961705'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2574563985'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2141139791'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2127468857'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2118888250'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2114599483'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2102769145'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2102599504'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '1897528164'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '236695653'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2028748157'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2278402735'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '651149800'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '2511404109'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2180580011',
#    'rel': 'COAUTHOR',
#    'end': '1981857495'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2106066026',
#    'rel': 'COAUTHOR',
#    'end': '2170211388'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2106066026',
#    'rel': 'COAUTHOR',
#    'end': '2102151894'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2106066026',
#    'rel': 'COAUTHOR',
#    'end': '209025647'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2106066026',
#    'rel': 'COAUTHOR',
#    'end': '2069913381'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2106066026',
#    'rel': 'COAUTHOR',
#    'end': '179829666'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2106066026',
#    'rel': 'COAUTHOR',
#    'end': '665967887'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2106066026',
#    'rel': 'COAUTHOR',
#    'end': '2471866511'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2106066026',
#    'rel': 'COAUTHOR',
#    'end': '2141048857'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2106066026',
#    'rel': 'COAUTHOR',
#    'end': '1660824135'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2106066026',
#    'rel': 'COAUTHOR',
#    'end': '2798377603'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2106066026',
#    'rel': 'COAUTHOR',
#    'end': '2604555504'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2106066026',
#    'rel': 'COAUTHOR',
#    'end': '2604161797'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2106066026',
#    'rel': 'COAUTHOR',
#    'end': '2195979361'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2106066026',
#    'rel': 'COAUTHOR',
#    'end': '2020994241'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2106066026',
#    'rel': 'COAUTHOR',
#    'end': '2487863865'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2106066026',
#    'rel': 'COAUTHOR',
#    'end': '2575624508'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2106066026',
#    'rel': 'COAUTHOR',
#    'end': '2613418797'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2106066026',
#    'rel': 'COAUTHOR',
#    'end': '2810623515'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2106066026',
#    'rel': 'COAUTHOR',
#    'end': '2810066588'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2106066026',
#    'rel': 'COAUTHOR',
#    'end': '53745947'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2106066026',
#    'rel': 'COAUTHOR',
#    'end': '2798833447'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2106066026',
#    'rel': 'COAUTHOR',
#    'end': '2307316253'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2106066026',
#    'rel': 'COAUTHOR',
#    'end': '2056820380'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2106066026',
#    'rel': 'COAUTHOR',
#    'end': '162475412'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2106066026',
#    'rel': 'COAUTHOR',
#    'end': '2889952385'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2106066026',
#    'rel': 'COAUTHOR',
#    'end': '2327334515'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2106066026',
#    'rel': 'COAUTHOR',
#    'end': '2106066026'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2106066026',
#    'rel': 'COAUTHOR',
#    'end': '1777014857'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2106066026',
#    'rel': 'COAUTHOR',
#    'end': '2710205647'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2106066026',
#    'rel': 'COAUTHOR',
#    'end': '2096556772'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2106066026',
#    'rel': 'COAUTHOR',
#    'end': '271170120'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2106066026',
#    'rel': 'COAUTHOR',
#    'end': '2116226955'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2106066026',
#    'rel': 'COAUTHOR',
#    'end': '608649841'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2106066026',
#    'rel': 'COAUTHOR',
#    'end': '192042342'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2106066026',
#    'rel': 'COAUTHOR',
#    'end': '571653231'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2106066026',
#    'rel': 'COAUTHOR',
#    'end': '2803383774'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2106066026',
#    'rel': 'COAUTHOR',
#    'end': '2676947192'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '665967887',
#    'rel': 'COAUTHOR',
#    'end': '2047615342'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '665967887',
#    'rel': 'COAUTHOR',
#    'end': '2106066026'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '665967887',
#    'rel': 'COAUTHOR',
#    'end': '2626982969'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '665967887',
#    'rel': 'COAUTHOR',
#    'end': '2471866511'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '665967887',
#    'rel': 'COAUTHOR',
#    'end': '2794259323'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '665967887',
#    'rel': 'COAUTHOR',
#    'end': '2154686538'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '665967887',
#    'rel': 'COAUTHOR',
#    'end': '2777194247'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '665967887',
#    'rel': 'COAUTHOR',
#    'end': '2669838597'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '665967887',
#    'rel': 'COAUTHOR',
#    'end': '2608616071'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '665967887',
#    'rel': 'COAUTHOR',
#    'end': '2557665619'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '665967887',
#    'rel': 'COAUTHOR',
#    'end': '296087741'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '665967887',
#    'rel': 'COAUTHOR',
#    'end': '2575624508'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '665967887',
#    'rel': 'COAUTHOR',
#    'end': '2011658732'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '665967887',
#    'rel': 'COAUTHOR',
#    'end': '2676808692'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '665967887',
#    'rel': 'COAUTHOR',
#    'end': '1927824781'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '665967887',
#    'rel': 'COAUTHOR',
#    'end': '2889952385'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '665967887',
#    'rel': 'COAUTHOR',
#    'end': '271170120'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '665967887',
#    'rel': 'COAUTHOR',
#    'end': '120731202'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '665967887',
#    'rel': 'COAUTHOR',
#    'end': '2149506619'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '665967887',
#    'rel': 'COAUTHOR',
#    'end': '2128384848'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '665967887',
#    'rel': 'COAUTHOR',
#    'end': '2562878240'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '665967887',
#    'rel': 'COAUTHOR',
#    'end': '1827383223'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '665967887',
#    'rel': 'COAUTHOR',
#    'end': '2122324641'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '665967887',
#    'rel': 'COAUTHOR',
#    'end': '2149556533'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '665967887',
#    'rel': 'COAUTHOR',
#    'end': '2136403997'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '665967887',
#    'rel': 'COAUTHOR',
#    'end': '2136971860'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '665967887',
#    'rel': 'COAUTHOR',
#    'end': '2667478766'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '665967887',
#    'rel': 'COAUTHOR',
#    'end': '571653231'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '665967887',
#    'rel': 'COAUTHOR',
#    'end': '2304800062'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '665967887',
#    'rel': 'COAUTHOR',
#    'end': '2578149252'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '665967887',
#    'rel': 'COAUTHOR',
#    'end': '2164959801'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '665967887',
#    'rel': 'COAUTHOR',
#    'end': '2151286743'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '665967887',
#    'rel': 'COAUTHOR',
#    'end': '2135064854'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '665967887',
#    'rel': 'COAUTHOR',
#    'end': '1969045844'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '665967887',
#    'rel': 'COAUTHOR',
#    'end': '2227238274'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '665967887',
#    'rel': 'COAUTHOR',
#    'end': '2803383774'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '665967887',
#    'rel': 'COAUTHOR',
#    'end': '2664326051'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '665967887',
#    'rel': 'COAUTHOR',
#    'end': '2393377300'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '665967887',
#    'rel': 'COAUTHOR',
#    'end': '2656850850'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '665967887',
#    'rel': 'COAUTHOR',
#    'end': '2398279864'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '665967887',
#    'rel': 'COAUTHOR',
#    'end': '2079079844'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '665967887',
#    'rel': 'COAUTHOR',
#    'end': '2799228685'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '665967887',
#    'rel': 'COAUTHOR',
#    'end': '2798983957'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '665967887',
#    'rel': 'COAUTHOR',
#    'end': '2798788556'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '665967887',
#    'rel': 'COAUTHOR',
#    'end': '2798638393'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '665967887',
#    'rel': 'COAUTHOR',
#    'end': '2702717237'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '665967887',
#    'rel': 'COAUTHOR',
#    'end': '2141048857'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2237022307',
#    'rel': 'COAUTHOR',
#    'end': '2160073445'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2237022307',
#    'rel': 'COAUTHOR',
#    'end': '2806000394'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2237022307',
#    'rel': 'COAUTHOR',
#    'end': '2644834195'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2237022307',
#    'rel': 'COAUTHOR',
#    'end': '2116264817'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2237022307',
#    'rel': 'COAUTHOR',
#    'end': '2115706870'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2237022307',
#    'rel': 'COAUTHOR',
#    'end': '1993407282'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2237022307',
#    'rel': 'COAUTHOR',
#    'end': '1993389174'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2237022307',
#    'rel': 'COAUTHOR',
#    'end': '1979586021'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2237022307',
#    'rel': 'COAUTHOR',
#    'end': '2679862359'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2237022307',
#    'rel': 'COAUTHOR',
#    'end': '21356295'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2237022307',
#    'rel': 'COAUTHOR',
#    'end': '2617302917'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2237022307',
#    'rel': 'COAUTHOR',
# ...
#    'end': '2107865364'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '743854149',
#    'rel': 'COAUTHOR',
#    'end': '1994732838'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '743854149',
#    'rel': 'COAUTHOR',
#    'end': '1976849332'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '743854149',
#    'rel': 'COAUTHOR',
#    'end': '297720247'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '743854149',
#    'rel': 'COAUTHOR',
#    'end': '2558693959'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '743854149',
#    'rel': 'COAUTHOR',
#    'end': '1987599005'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '743854149',
#    'rel': 'COAUTHOR',
#    'end': '2578474771'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '743854149',
#    'rel': 'COAUTHOR',
#    'end': '2108891702'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '743854149',
#    'rel': 'COAUTHOR',
#    'end': '2320250993'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '743854149',
#    'rel': 'COAUTHOR',
#    'end': '2557487714'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '743854149',
#    'rel': 'COAUTHOR',
#    'end': '2117853988'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '743854149',
#    'rel': 'COAUTHOR',
#    'end': '2156502381'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '743854149',
#    'rel': 'COAUTHOR',
#    'end': '329666814'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '743854149',
#    'rel': 'COAUTHOR',
#    'end': '2568534056'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '743854149',
#    'rel': 'COAUTHOR',
#    'end': '1726875417'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '743854149',
#    'rel': 'COAUTHOR',
#    'end': '2123861497'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '743854149',
#    'rel': 'COAUTHOR',
#    'end': '1824633460'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '743854149',
#    'rel': 'COAUTHOR',
#    'end': '1975873816'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '743854149',
#    'rel': 'COAUTHOR',
#    'end': '2102151894'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '743854149',
#    'rel': 'COAUTHOR',
#    'end': '2166504681'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '743854149',
#    'rel': 'COAUTHOR',
#    'end': '2168762576'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '743854149',
#    'rel': 'COAUTHOR',
#    'end': '2099079987'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2166269414',
#    'rel': 'COAUTHOR',
#    'end': '2630697985'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2166269414',
#    'rel': 'COAUTHOR',
#    'end': '2115880751'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2166269414',
#    'rel': 'COAUTHOR',
#    'end': '1971735452'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2166269414',
#    'rel': 'COAUTHOR',
#    'end': '2555530518'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2166269414',
#    'rel': 'COAUTHOR',
#    'end': '2050870929'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2166269414',
#    'rel': 'COAUTHOR',
#    'end': '2006063360'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2166269414',
#    'rel': 'COAUTHOR',
#    'end': '2146398068'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2166269414',
#    'rel': 'COAUTHOR',
#    'end': '2109958197'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2166269414',
#    'rel': 'COAUTHOR',
#    'end': '2402142895'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2616734777',
#    'rel': 'COAUTHOR',
#    'end': '2313193659'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2313193659',
#    'rel': 'COAUTHOR',
#    'end': '2057547094'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2313193659',
#    'rel': 'COAUTHOR',
#    'end': '2626318345'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2313193659',
#    'rel': 'COAUTHOR',
#    'end': '2172737460'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2313193659',
#    'rel': 'COAUTHOR',
#    'end': '2044075482'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2313193659',
#    'rel': 'COAUTHOR',
#    'end': '2474495204'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2313193659',
#    'rel': 'COAUTHOR',
#    'end': '2260550305'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2313193659',
#    'rel': 'COAUTHOR',
#    'end': '742588681'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2313193659',
#    'rel': 'COAUTHOR',
#    'end': '659117755'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2313193659',
#    'rel': 'COAUTHOR',
#    'end': '2093315205'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2313193659',
#    'rel': 'COAUTHOR',
#    'end': '2128384848'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2313193659',
#    'rel': 'COAUTHOR',
#    'end': '2679810246'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2313193659',
#    'rel': 'COAUTHOR',
#    'end': '2616734777'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2313193659',
#    'rel': 'COAUTHOR',
#    'end': '2313193659'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2700545239'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2230111470'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2143287653'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2070705392'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2018432004'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '1415625156'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2797981432'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2797187347'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2797122357'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2796699848'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2779593801'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2748313325'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2718151956'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2685087918'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2532501611'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2338174001'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2149214673'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '1969633589'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '938539593'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2551554383'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2108546891'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2012431701'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2798815963'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2798621201'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2478689860'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2444141713'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2093990278'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '1811385217'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '238369536'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2313972120'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2187391243'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2116001583'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2714519111'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2638520482'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '1982021776'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '11092920'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2647078213'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2564763014'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2380058866'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2327615538'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2282942822'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2277049365'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2223603043'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2165779820'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2151556379'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2106127867'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2096596663'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2071236665'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2066724235'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '1927264516'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2140074598'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2794111417'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2664088284'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '125803765'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2232488985'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2762323890'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '1879501016'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2749104472'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2585088502'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2233782923'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2159122582'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2143760997'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2722586664'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2720257861'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2708258847'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2691651900'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2657589242'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2656564491'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2652700305'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2522084109'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2232816687'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2098359706'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2089581441'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2057498366'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2289502675'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2190197533'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2747009252'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2331501075'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2018813508'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2667172084'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2608402196'}},
#  {'{start:a.authorId,rel:"COAUTHOR",end:a2.authorId}': {'start': '2444141713',
#    'rel': 'COAUTHOR',
#    'end': '2288267481'}}]

# %%
def authors_to_graph(authorPairs):
    edge_list = [(p['a1']["normalizedName"], p['a2']['normalizedName']) for p in authorPairs]
    G = nx.DiGraph()
    G.add_edges_from(edge_list)
    return nx.convert_node_labels_to_integers(G)

def get_cited_relations(fieldOfStudyName):
    CITED_QUERY = """
        MATCH (p1:Paper)-[:IN_FIELD]->(parent:FieldsOfStudy{normalizedName: $fosName})
        WHERE p1.citationCount > 0 AND p1.referenceCount > 0 AND p1.docType = "Journal" WITH p1
        MATCH (p1:Paper)-[r:REFERENCES]->(p2:Paper)
        WHERE p2.citationCount > 0 AND p2.referenceCount > 0 AND p2.docType = "Journal" WITH p1, p2
        MATCH (p2:Paper)-[:AUTHORED_BY]->(a2:Author)<-[:AUTHORED_BY]-(:Paper)-[:IN_FIELD]->(parent:FieldsOfStudy{normalizedName: $fosName})
        WITH p1, a2
        MATCH (p1:Paper)-[:AUTHORED_BY]->(a1:Author)
        RETURN DISTINCT a1, a2
        LIMIT 50000
    """
    with driver.session() as session:
        return session.run(CITED_QUERY, fosName=fieldOfStudyName).data()

# %%
def authors_to_graph(authorPairs):
    edge_list = [(p['a1']["normalizedName"], p['a2']['normalizedName']) for p in authorPairs]
    G = nx.DiGraph()
    G.add_edges_from(edge_list)
    return nx.convert_node_labels_to_integers(G)

# %%
rels = get_cited_relations("social epistemology")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-351-d1d55fc001ac> in get_cited_relations(fieldOfStudyName)
#      13     with driver.session() as session:
# ---> 14         return session.run(CITED_QUERY, fosName=fieldOfStudyName).data()
#
# /usr/local/lib/python3.7/site-packages/neo4j/__init__.py in data(self, *items)
#    1052         """
# -> 1053         return [record.data(*items) for record in self.records()]
#    1054
#
# /usr/local/lib/python3.7/site-packages/neo4j/__init__.py in <listcomp>(.0)
#    1052         """
# -> 1053         return [record.data(*items) for record in self.records()]
#    1054
#
# /usr/local/lib/python3.7/site-packages/neo4j/__init__.py in records(self)
#     951         while attached():
# --> 952             self._session.fetch()
#     953             while records:
#
# /usr/local/lib/python3.7/site-packages/neo4j/__init__.py in fetch(self)
#     526             try:
# --> 527                 detail_count, _ = self._connection.fetch()
#     528             except ConnectionExpired as error:
#
# /usr/local/lib/python3.7/site-packages/neobolt/direct.py in fetch(self)
#     421         try:
# --> 422             return self._fetch()
#     423         except self.error_handler.known_errors as error:
#
# /usr/local/lib/python3.7/site-packages/neobolt/direct.py in _fetch(self)
#     442
# --> 443         self._receive()
#     444
#
# /usr/local/lib/python3.7/site-packages/neobolt/direct.py in _receive(self)
#     492         elif received == -1:
# --> 493             raise KeyboardInterrupt()
#     494
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-360-65c06fe7e368> in <module>
# ----> 1 rels = get_cited_relations("social epistemology")
#
# <ipython-input-351-d1d55fc001ac> in get_cited_relations(fieldOfStudyName)
#      12     """
#      13     with driver.session() as session:
# ---> 14         return session.run(CITED_QUERY, fosName=fieldOfStudyName).data()
#
# /usr/local/lib/python3.7/site-packages/neo4j/__init__.py in __exit__(self, exc_type, exc_value, traceback)
#     372
#     373     def __exit__(self, exc_type, exc_value, traceback):
# --> 374         self.close()
#     375
#     376     def _connect(self, access_mode=None):
#
# /usr/local/lib/python3.7/site-packages/neo4j/__init__.py in close(self)
#     397                 self._transaction = None
#     398             try:
# --> 399                 self._connection.sync()
#     400             except (ConnectionExpired, CypherError, TransactionError,
#     401                     ServiceUnavailable, SessionError):
#
# /usr/local/lib/python3.7/site-packages/neobolt/direct.py in sync(self)
#     529             response = self.responses[0]
#     530             while not response.complete:
# --> 531                 detail_delta, summary_delta = self.fetch()
#     532                 detail_count += detail_delta
#     533                 summary_count += summary_delta
#
# /usr/local/lib/python3.7/site-packages/neobolt/direct.py in fetch(self)
#     420     def fetch(self):
#     421         try:
# --> 422             return self._fetch()
#     423         except self.error_handler.known_errors as error:
#     424             self.error_handler.handle(error, self.unresolved_address)
#
# /usr/local/lib/python3.7/site-packages/neobolt/direct.py in _fetch(self)
#     441             return 0, 0
#     442
# --> 443         self._receive()
#     444
#     445         details, summary_signature, summary_metadata = self._unpack()
#
# /usr/local/lib/python3.7/site-packages/neobolt/direct.py in _receive(self)
#     491             raise self.Error(message)
#     492         elif received == -1:
# --> 493             raise KeyboardInterrupt()
#     494
#     495     def _unpack(self):
#
# KeyboardInterrupt:

# %%
g = authors_to_graph(rels)
print("Number nodes: {}".format(len(g.nodes())))
print("Number edges: {}".format(len(g.edges())))
print("Average clustering coefficient: {}".format(nx.average_clustering(g)))
print("Number strongly connected components: {}".format(nx.number_strongly_connected_components(g)))
print("Number weakly connected components: {}".format(nx.number_weakly_connected_components(g)))
nx.write_graphml(g, "social_epistemology.graphml")
# Out:
# Number nodes: 799
# Number edges: 1999
# Average clustering coefficient: 0.12939346623157844
# Number strongly connected components: 723
# Number weakly connected components: 78

# %%
ling_rels = get_cited_relations("sociolinguistics")

# %%
ling_g = authors_to_graph(ling_rels)
print("Number nodes: {}".format(len(ling_g.nodes())))
print("Number edges: {}".format(len(ling_g.edges())))
print("Average clustering coefficient: {}".format(nx.average_clustering(ling_g)))
print("Number strongly connected components: {}".format(nx.number_strongly_connected_components(ling_g)))
print("Number weakly connected components: {}".format(nx.number_weakly_connected_components(ling_g)))
nx.write_graphml(ling_g, "sociolinguistics.graphml")
# Out:
# Number nodes: 4188
# Number edges: 23485
# Average clustering coefficient: 0.1681175586475732
# Number strongly connected components: 3064
# Number weakly connected components: 66
